# %%
import pandas as pd

from IPython.display import display

pd.options.display.float_format = "{:,.2g}".format
pd.set_option('display.max_rows', 500)

df = pd.read_json("dataset.json")

df.head()
# Out:
#       track        domain                                  runtimes-training  \
# 0  opt-1204        barman  [0.5, 0.85, 3.13, 10.54, 61.47, unsolved, unso...
# 1  opt-1204   blocksworld  [0.48, 0.52, 0.5, 0.5700000000000001, 1.02, 1....
# 2  opt-1204    childsnack  [7.15, 54.11, 31.23, unsolved, unsolved, unsol...
# 3  opt-1204  data-network  [unsolved, unsolved, unsolved, 188.05, 149.27,...
# 4  opt-1204        depots  [0.87, 0.71, 30.35, 486.57, unsolved, unsolved...
#
#                                        runtimes-eval  \
# 0  [0.51, 1.17, 2.77, 43.26, 208.01, unsolved, un...
# 1  [0.5, 0.52, 0.5, 0.71, 1.06, 3.19, 4.69, 2.09,...
# 2  [1.09, 2.71, 32.52, 497.97, unsolved, unsolved...
# 3  [370.74, unsolved, unsolved, 440.22, 176.71, u...
# 4  [0.93, 0.9400000000000001, 39.26, 249.12, 458....
#
#                                             coverage  \
# 0  {'fd1906-bjolp': 7, 'fd1906-blind': 7, 'fd1906...
# 1  {'fd1906-bjolp': 9, 'fd1906-blind': 6, 'fd1906...
# 2  {'fd1906-bjolp': 7, 'fd1906-blind': 7, 'fd1906...
# 3  {'fd1906-bjolp': 7, 'fd1906-blind': 4, 'fd1906...
# 4  {'fd1906-bjolp': 13, 'fd1906-blind': 6, 'fd190...
#
#                                         coverage-ipc covrange-training  \
# 0  {'fd1906-bjolp': 4, 'fd1906-blind': 4, 'fd1906...              7-13
# 1  {'fd1906-bjolp': 28, 'fd1906-blind': 18, 'fd19...              6-12
# 2  {'ipc2014-opt-symba1': 4, 'ipc2018-opt-complem...              7-17
# 3  {'fd1906-bjolp': 11, 'fd1906-blind': 7, 'fd190...              4-11
# 4  {'fd1906-bjolp': 9, 'fd1906-blind': 4, 'fd1906...              6-13
#
#   covrange-ipc-training covrange-eval covrange-ipc-eval  ...  \
# 0                  4-16          8-12              4-11  ...
# 1                 18-34          5-12             18-30  ...
# 2                   4-4          7-19               1-6  ...
# 3                  7-13          4-14              6-14  ...
# 4                   4-9          7-22              5-14  ...
#
#    gmean_factorg5_runtime_eval  coverage-estimated  coverage-training  \
# 0                          1.6                  18                 13
# 1                          1.9                  13                 12
# 2                          1.7                  20                 17
# 3                          1.7                  15                 12
# 4                          1.4                  19                 13
#
#    estimated-error-coverage  estimated-instance-error-coverage  \
# 0                         5                                  5
# 1                         1                                  1
# 2                         3                                  3
# 3                         3                                  9
# 4                         6                                  6
#
#    estimated-instance-error-runtime  estimated-error-runtime  \
# 0                                82                      1.5
# 1                             8e+02                      1.3
# 2                             1e+03                      1.5
# 3                           1.1e+03                      2.6
# 4                           1.5e+03                      2.5
#
#    penalty-estimated  penalty-training  penalty-eval
# 0                1.4               1.4          0.66
# 1                1.7               2.6           1.4
# 2               0.79               1.7           1.1
# 3                1.9               1.7           1.9
# 4               0.25                 2           1.9
#
# [5 rows x 85 columns]

# %%
pd.options.display.float_format = "{:,.2g}".format
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 100000)


display(list(df[df['track'] == "opt-1210"][df['domain'] == "openstacks"]["coverage"].items()))
display(list(df[df['track'] == "opt-1210"][df['domain'] == "openstacks"]["coverage-ipc"].items()))
# Out:
# <ipython-input-88-aa8dde0f5739>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   display(list(df[df['track'] == "opt-1210"][df['domain'] == "openstacks"]["coverage"].items()))
# [(66,
#   {'fd1906-bjolp': 4,
#    'fd1906-blind': 4,
#    'fd1906-fdss1-mas1-60s': 3,
#    'fd1906-fdss1-mas2-60s': 4,
#    'fd1906-lmcut': 4,
#    'ipc2014-opt-symba1': 20,
#    'ipc2018-opt-complementary2-3584mb': 6,
#    'ipc2018-opt-decstar': 4,
#    'ipc2018-opt-delfi-blind': 4,
#    'ipc2018-opt-delfi-celmcut': 4,
#    'ipc2018-opt-delfi-ipdb': 4,
#    'ipc2018-opt-delfi-mas-miasm': 4,
#    'ipc2018-opt-delfi-mas-sccdfp': 4,
#    'ipc2018-opt-scorpion': 4})]
# <ipython-input-88-aa8dde0f5739>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   display(list(df[df['track'] == "opt-1210"][df['domain'] == "openstacks"]["coverage-ipc"].items()))
# [(66,
#   {'fd1906-bjolp': 40,
#    'fd1906-blind': 42,
#    'fd1906-fdss1-mas1-60s': 23,
#    'fd1906-fdss1-mas2-60s': 42,
#    'fd1906-lmcut': 42,
#    'ipc2014-opt-symba1': 70,
#    'ipc2018-opt-complementary2-3584mb': 64,
#    'ipc2018-opt-decstar': 44,
#    'ipc2018-opt-delfi-blind': 47,
#    'ipc2018-opt-delfi-celmcut': 45,
#    'ipc2018-opt-delfi-ipdb': 47,
#    'ipc2018-opt-delfi-mas-miasm': 44,
#    'ipc2018-opt-delfi-mas-sccdfp': 47,
#    'ipc2018-opt-scorpion': 42})]

# %%
# Attributes to include in the paper
columns = ["track", "domain", "num_sequences", "covrange-ipc-training", "covrange-trainng", "comparisons-training", "comparisons-training-ipcdiff", "covrange-ipc-eval", "covrange-eval", "comparisons-eval", "comparisons-eval-ipcdiff",]    

display(df[df['track'] == "opt-1210"].filter(columns))

display(df[df['track'] == "sat-1210"].filter(columns))
# Out:
#        track        domain  num_sequences covrange-ipc-training  \
# 52  opt-1210        barman              3                  4-16
# 53  opt-1210   blocksworld              1                 18-34
# 54  opt-1210    childsnack              3                   4-4
# 55  opt-1210  data-network              2                  7-13
# 56  opt-1210        depots              3                   4-9
# 57  opt-1210     driverlog              1                  7-14
# 58  opt-1210     elevators              3                  7-44
# 59  opt-1210     floortile              2                  2-34
# 60  opt-1210          grid              1                   1-3
# 61  opt-1210       gripper              1                  7-20
# 62  opt-1210        hiking              2                  9-19
# 63  opt-1210     logistics              2                 12-27
# 64  opt-1210       miconic              2                55-144
# 65  opt-1210     nomystery              2                  8-20
# 66  opt-1210    openstacks              1                 23-70
# 67  opt-1210       parking              4                  1-11
# 68  opt-1210        rovers              2                  6-14
# 69  opt-1210     satellite              2                  6-10
# 70  opt-1210    scanalyzer              3                 15-29
# 71  opt-1210         snake              2                  4-12
# 72  opt-1210       storage              2                 14-16
# 73  opt-1210           tpp              2                   6-8
# 74  opt-1210     transport              1                 23-33
# 75  opt-1210      visitall              2                 12-28
# 76  opt-1210   woodworking              3                 11-48
# 77  opt-1210    zenotravel              2                  8-13
#
#     comparisons-training  comparisons-training-ipcdiff covrange-ipc-eval  \
# 52                    14                             9              4-11
# 53                    14                             2             18-30
# 54                     5                             0               1-6
# 55                    14                            -1              6-14
# 56                    13                             4              5-14
# 57                    15                             4              7-15
# 58                    13                            -2             28-44
# 59                    15                             2             16-34
# 60                    14                             3               1-3
# 61                    11                             0              8-20
# 62                    12                            -2             13-18
# 63                    15                             1             13-36
# 64                    15                             1            56-143
# 65                    14                             0              8-20
# 66                     9                            -3             42-64
# 67                    14                            -1              1-15
# 68                    14                             1              6-13
# 69                    15                             3              7-14
# 70                     5                            -4             21-33
# 71                    12                             0              7-14
# 72                    12                             3             15-18
# 73                    12                             1              7-20
# 74                     9                            -5             24-35
# 75                    15                             0             12-30
# 76                    14                             2             38-50
# 77                    14                             0              7-13
#
#    covrange-eval  comparisons-eval  comparisons-eval-ipcdiff
# 52         10-16                24                        12
# 53          5-12                24                         6
# 54          8-19                21                         8
# 55          8-17                25                        -2
# 56         11-19                25                         0
# 57          4-30                27                         5
# 58          8-11                23                        -3
# 59          8-16                18                        -3
# 60          5-14                26                         7
# 61          9-30                 7                         0
# 62          2-16                25                         4
# 63          8-30                25                        -3
# 64          3-21                27                         0
# 65          3-30                28                        10
# 66           4-6                 7                       -17
# 67         12-19                26                        -2
# 68          5-27                22                        -4
# 69         14-27                26                         5
# 70          9-19                26                         0
# 71          7-15                21                        -1
# 72          8-23                27                         6
# 73          4-30                26                         2
# 74          6-30                13                        -8
# 75          6-20                26                         0
# 76         15-25                26                         5
# 77          3-29                27                         4
#         track        domain  num_sequences covrange-ipc-training  \
# 78   sat-1210        barman              1                 17-40
# 79   sat-1210   blocksworld              1                 35-35
# 80   sat-1210    childsnack              2                   1-7
# 81   sat-1210  data-network              1                  2-15
# 82   sat-1210        depots              1                 17-22
# 83   sat-1210     driverlog              1                 18-20
# 84   sat-1210     elevators              1                 11-50
# 85   sat-1210     floortile              1                  7-40
# 86   sat-1210          grid              1                   4-5
# 87   sat-1210       gripper              1                 20-20
# 88   sat-1210        hiking              2                  1-20
# 89   sat-1210     logistics              2                 57-63
# 90   sat-1210       miconic              1               150-150
# 91   sat-1210     nomystery              1                  6-20
# 92   sat-1210    openstacks              1                36-100
# 93   sat-1210       parking              1                 23-40
# 94   sat-1210        rovers              1                 26-40
# 95   sat-1210     satellite              1                 28-36
# 96   sat-1210    scanalyzer              2                 42-50
# 97   sat-1210         snake              2                  5-12
# 98   sat-1210       storage              1                 19-30
# 99   sat-1210           tpp              1                 23-30
# 100  sat-1210     transport              1                 13-70
# 101  sat-1210      visitall              1                  3-40
# 102  sat-1210   woodworking              1                 43-50
# 103  sat-1210    zenotravel              1                 20-20
#
#      comparisons-training  comparisons-training-ipcdiff covrange-ipc-eval  \
# 78                     15                             2             39-40
# 79                     15                            15             35-35
# 80                     15                             2              1-20
# 81                     14                             0              9-19
# 82                     15                             3             22-22
# 83                     15                            10             20-20
# 84                     15                             6             49-50
# 85                      9                            -5              4-40
# 86                     13                             8               5-5
# 87                      0                             0             20-20
# 88                     14                             5             10-20
# 89                     12                             0             51-63
# 90                      0                             0           150-150
# 91                     15                             1             12-20
# 92                     14                             0            70-100
# 93                     15                             1             35-40
# 94                     13                             8             38-40
# 95                     15                             1             26-36
# 96                     13                             1             48-50
# 97                     14                             2              3-17
# 98                     14                             0             21-30
# 99                     15                             6             29-30
# 100                    15                             1             62-70
# 101                    15                             3             36-40
# 102                    14                             9             28-50
# 103                    13                            13             20-20
#
#     covrange-eval  comparisons-eval  comparisons-eval-ipcdiff
# 78           4-20                26                        19
# 79           6-21                26                        26
# 80           2-30                28                         1
# 81          16-30                26                         2
# 82          14-21                25                        25
# 83           8-25                25                        25
# 84          14-30                18                        11
# 85           2-12                24                         7
# 86          12-16                21                        21
# 87          26-30                 7                         7
# 88           2-25                25                         3
# 89           7-15                21                         4
# 90          30-30                 0                         0
# 91           6-30                27                         4
# 92          12-21                25                        10
# 93          15-18                18                         5
# 94          15-30                27                        20
# 95           4-17                25                         2
# 96          11-13                20                         8
# 97           2-20                27                         0
# 98           8-19                27                         1
# 99           8-20                26                        11
# 100          9-16                21                        14
# 101         19-30                24                        17
# 102          3-30                27                        14
# 103          6-14                22                        22

# %%
# Other relevant attributes of interest 
columns = ["domain", "penalty-estimated", "penalty-training", "penalty-eval", "gmean_factorg5_runtime_training",
           "gmean_factorg5_runtime_eval", "comparisons-all", "comparisons-all-ipcdiff"]

display(df[df['track'] == "opt-1210"].filter(columns))
display(df[df['track'] == "sat-1210"].filter(columns))
# Out:
#           domain  penalty-estimated  penalty-training  penalty-eval  \
# 52        barman               0.44               1.2           1.2
# 53   blocksworld                1.7               2.4           1.4
# 54    childsnack                  2               1.8           1.4
# 55  data-network                1.5               1.2          0.87
# 56        depots                1.6               1.3           1.9
# 57     driverlog               0.91               1.7           6.8
# 58     elevators                1.8               1.3          0.67
# 59     floortile               0.81              0.95           1.7
# 60          grid               0.32               1.9             1
# 61       gripper               0.69                 8            10
# 62        hiking              0.095               0.1          0.05
# 63     logistics                  2               1.3            10
# 64       miconic                2.6               2.8          0.56
# 65     nomystery                1.4              0.28           2.5
# 66    openstacks               0.68               1.8           4.8
# 67       parking                1.2              0.74           2.4
# 68        rovers                1.9               1.7           2.2
# 69     satellite                2.3               1.2           3.1
# 70    scanalyzer                1.8               1.2           1.5
# 71         snake                1.5              0.25           2.2
# 72       storage                1.3               2.1           1.8
# 73           tpp                2.4               2.2           1.8
# 74     transport                1.2               1.4           2.3
# 75      visitall               0.92               1.3          0.67
# 76   woodworking                1.8               1.7           2.5
# 77    zenotravel                  1               1.2             7
#
#    gmean_factorg5_runtime_training gmean_factorg5_runtime_eval  \
# 52                             1.8                         1.5
# 53                             2.1                         1.9
# 54                             1.4                         1.8
# 55                             2.4                         1.9
# 56                             3.4                         1.7
# 57                             1.8                         8.7
# 58                             1.5                           2
# 59                             1.5                         1.9
# 60                             1.8                         1.8
# 61                               -                           -
# 62                             1.4                         1.4
# 63                             1.9                           -
# 64                             2.4                           2
# 65                             1.7                         1.2
# 66                             1.4                         4.1
# 67                             2.1                         1.9
# 68                             1.5                         1.3
# 69                             2.4                         1.5
# 70                             1.8                         1.7
# 71                             2.1                         1.5
# 72                             1.9                         1.6
# 73                             1.8                         1.1
# 74                             1.4                         1.2
# 75                             1.4                         1.6
# 76                             1.7                         1.9
# 77                             1.6                           1
#
#     comparisons-all  comparisons-all-ipcdiff
# 52               83                       28
# 53               79                       17
# 54               69                        8
# 55               78                       -7
# 56               77                        2
# 57               88                       23
# 58               78                       -7
# 59               76                       -4
# 60               82                       23
# 61               49                        0
# 62               82                        2
# 63               87                        1
# 64               85                       -3
# 65               88                       19
# 66               36                      -45
# 67               81                       -6
# 68               73                      -10
# 69               89                       10
# 70               74                       -5
# 71               66                       -2
# 72               83                       13
# 73               85                        9
# 74               70                       -3
# 75               85                        0
# 76               88                        7
# 77               88                       12
#            domain  penalty-estimated  penalty-training  penalty-eval  \
# 78         barman                1.7               1.7          0.99
# 79    blocksworld                2.2               1.4           1.9
# 80     childsnack                2.7               4.1           2.1
# 81   data-network                1.1               3.2           2.7
# 82         depots               0.64              0.55          0.54
# 83      driverlog               0.71                 1          0.94
# 84      elevators                1.2               2.7           1.3
# 85      floortile               0.26               0.4           1.6
# 86           grid               0.18               1.2           1.5
# 87        gripper                2.1                10            10
# 88         hiking               0.19             0.091           1.8
# 89      logistics                1.6               1.6           2.5
# 90        miconic                2.9                10           3.2
# 91      nomystery                2.5               2.4           2.5
# 92     openstacks              0.032              0.32          0.37
# 93        parking               0.85               1.2          0.99
# 94         rovers                1.9               1.5           2.6
# 95      satellite               0.84              0.71           1.2
# 96     scanalyzer               0.18             0.032         0.076
# 97          snake               0.56              0.77             1
# 98        storage               0.67              0.69          0.91
# 99            tpp               0.66               2.3          0.84
# 100     transport               0.21              0.51             0
# 101      visitall               0.97              0.57           1.2
# 102   woodworking               0.34                 1           1.7
# 103    zenotravel                  0              0.32          0.66
#
#     gmean_factorg5_runtime_training gmean_factorg5_runtime_eval  \
# 78                              1.3                         1.4
# 79                              1.3                         1.5
# 80                              3.1                         1.3
# 81                              1.4                         1.3
# 82                              1.4                         1.3
# 83                              1.5                         1.3
# 84                              1.1                         1.1
# 85                              1.5                         2.3
# 86                              1.7                         1.6
# 87                                -                           -
# 88                              1.6                         1.4
# 89                              1.3                         1.2
# 90                                -                         1.1
# 91                              1.2                         1.3
# 92                              1.3                         1.3
# 93                              1.3                         1.4
# 94                              1.2                         1.2
# 95                              1.4                         1.3
# 96                              1.5                         1.6
# 97                              1.2                         1.2
# 98                              1.5                         1.5
# 99                              1.3                         1.3
# 100                             1.4                         1.6
# 101                             1.3                         1.3
# 102                             1.4                         1.2
# 103                             1.5                         1.5
#
#      comparisons-all  comparisons-all-ipcdiff
# 78                89                       37
# 79                88                       88
# 80                88                        2
# 81                86                        3
# 82                86                       50
# 83                88                       75
# 84                74                       38
# 85                69                       -5
# 86                78                       65
# 87                13                       13
# 88                87                       25
# 89                68                        6
# 90                 0                        0
# 91                88                        5
# 92                85                       14
# 93                80                       17
# 94                86                       61
# 95                86                       11
# 96                77                       23
# 97                87                        3
# 98                89                        5
# 99                83                       34
# 100               80                       19
# 101               85                       39
# 102               87                       51
# 103               82                       82
